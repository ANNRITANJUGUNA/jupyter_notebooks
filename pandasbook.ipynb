# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
purchases = pd.DataFrame(data)

# %%
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

# %%
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.apples
# Out:
# June      3
# Robert    2
# Lily      0
# David     1
# Name: apples, dtype: int64

# %%
purchases['apples']
# Out:
# June      3
# Robert    2
# Lily      0
# David     1
# Name: apples, dtype: int64

# %%
purchases.columns
# Out:
# Index(['apples', 'oranges'], dtype='object')

# %% [markdown]
# Step1:IMPORTING DATA

# %%
sales = pd.read_csv('sales_data_sample.csv' ,engine='python',header=0, encoding='Windows-1252')

# %%
sales
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# Step2:CHECKING DATA TYPES

# %%
sales.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
sales.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %% [markdown]
# ## 5.SUMMARY STATISTICS

# %%
sales.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sales.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
columns=sales.columns
sales.columns=columns.map(str.lower,na_action=None)

# %%
sales.columns
# Out:
# Index(['ordernumber', 'quantityordered', 'priceeach', 'orderlinenumber',
#        'sales', 'orderdate', 'status', 'qtr_id', 'month_id', 'year_id',
#        'productline', 'msrp', 'productcode', 'customername', 'phone',
#        'addressline1', 'addressline2', 'city', 'state', 'postalcode',
#        'country', 'territory', 'contactlastname', 'contactfirstname',
#        'dealsize'],
#       dtype='object')

# %%
sales.std(numeric_only='None')
# Out:
# ordernumber          92.085478
# quantityordered       9.741443
# priceeach            20.174277
# orderlinenumber       4.225841
# sales              1841.865106
# qtr_id                1.203878
# month_id              3.656633
# year_id               0.699670
# msrp                 40.187912
# dtype: float64

# %%
sales.median(numeric_only='None')
# Out:
# ordernumber        10262.0
# quantityordered       35.0
# priceeach             95.7
# orderlinenumber        6.0
# sales               3184.8
# qtr_id                 3.0
# month_id               8.0
# year_id             2004.0
# msrp                  99.0
# dtype: float64

# %%
sales.mode(numeric_only='None')
# Out:
#    ordernumber  quantityordered  priceeach  orderlinenumber   sales  qtr_id  \
# 0        10106             34.0      100.0              1.0  3003.0     4.0
# 1        10159              NaN        NaN              NaN     NaN     NaN
# 2        10165              NaN        NaN              NaN     NaN     NaN
# 3        10168              NaN        NaN              NaN     NaN     NaN
# 4        10222              NaN        NaN              NaN     NaN     NaN
# 5        10275              NaN        NaN              NaN     NaN     NaN
# 6        10316              NaN        NaN              NaN     NaN     NaN
# 7        10332              NaN        NaN              NaN     NaN     NaN
# 8        10386              NaN        NaN              NaN     NaN     NaN
# 9        10398              NaN        NaN              NaN     NaN     NaN
#
#    month_id  year_id   msrp
# 0      11.0   2004.0  118.0
# 1       NaN      NaN    NaN
# 2       NaN      NaN    NaN
# ...

# %%
sales.min(numeric_only='None')
# Out:
# ordernumber        10100.00
# quantityordered        6.00
# priceeach             26.88
# orderlinenumber        1.00
# sales                482.13
# qtr_id                 1.00
# month_id               1.00
# year_id             2003.00
# msrp                  33.00
# dtype: float64

# %%
sales.max(numeric_only='None')
# Out:
# ordernumber        10425.0
# quantityordered       97.0
# priceeach            100.0
# orderlinenumber       18.0
# sales              14082.8
# qtr_id                 4.0
# month_id              12.0
# year_id             2005.0
# msrp                 214.0
# dtype: float64

# %%
sales.describe(include='all')
# Out:
#          ordernumber  quantityordered    priceeach  orderlinenumber  \
# count    2823.000000      2823.000000  2823.000000      2823.000000
# unique           NaN              NaN          NaN              NaN
# top              NaN              NaN          NaN              NaN
# freq             NaN              NaN          NaN              NaN
# mean    10258.725115        35.092809    83.658544         6.466171
# std        92.085478         9.741443    20.174277         4.225841
# min     10100.000000         6.000000    26.880000         1.000000
# 25%     10180.000000        27.000000    68.860000         3.000000
# 50%     10262.000000        35.000000    95.700000         6.000000
# 75%     10333.500000        43.000000   100.000000         9.000000
# max     10425.000000        97.000000   100.000000        18.000000
#
#                sales        orderdate   status       qtr_id     month_id  \
# count    2823.000000             2823     2823  2823.000000  2823.000000
# ...

# %%
sales.count()
# Out:
# ordernumber         2823
# quantityordered     2823
# priceeach           2823
# orderlinenumber     2823
# sales               2823
# orderdate           2823
# status              2823
# qtr_id              2823
# month_id            2823
# year_id             2823
# productline         2823
# msrp                2823
# productcode         2823
# customername        2823
# phone               2823
# addressline1        2823
# addressline2         302
# city                2823
# state               1337
# postalcode          2747
# country             2823
# territory           1749
# contactlastname     2823
# contactfirstname    2823
# dealsize            2823
# dtype: int64

# %%
pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.2/1.2 MB 993.6 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = sales.set_index('ordernumber')

# %%
df
# Out:
#              quantityordered  priceeach  orderlinenumber    sales  \
# ordernumber
# 10107                     30      95.70                2  2871.00
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
# ...                      ...        ...              ...      ...
# 10350                     20     100.00               15  2244.40
# 10373                     29     100.00                1  3978.51
# 10386                     43     100.00                4  5417.57
# 10397                     34      62.24                1  2116.16
# 10414                     47      65.52                9  3079.44
#
#                    orderdate    status  qtr_id  month_id  year_id  \
# ordernumber
# 10107         2/24/2003 0:00   Shipped       1         2     2003
# ...

# %%
temp_df = sales.append(sales)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2816\1208415351.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = sales.append(sales)

# %%
temp_df.shape
# Out:
# (5646, 25)

# %%
sales.shape
# Out:
# (2823, 25)

# %%
temp_df.drop_duplicates(inplace=True)

# %%
temp_df.shape
# Out:
# (2823, 25)

# %%
df.isnull().sum()
# Out:
# quantityordered        0
# priceeach              0
# orderlinenumber        0
# sales                  0
# orderdate              0
# status                 0
# qtr_id                 0
# month_id               0
# year_id                0
# productline            0
# msrp                   0
# productcode            0
# customername           0
# phone                  0
# addressline1           0
# addressline2        2521
# city                   0
# state               1486
# postalcode            76
# country                0
# territory           1074
# contactlastname        0
# contactfirstname       0
# dealsize               0
# dtype: int64

# %%
new_df=df.drop(['state','territory'],axis=1)

# %%
df
# Out:
#              quantityordered  priceeach  orderlinenumber    sales  \
# ordernumber
# 10107                     30      95.70                2  2871.00
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
# ...                      ...        ...              ...      ...
# 10350                     20     100.00               15  2244.40
# 10373                     29     100.00                1  3978.51
# 10386                     43     100.00                4  5417.57
# 10397                     34      62.24                1  2116.16
# 10414                     47      65.52                9  3079.44
#
#                    orderdate    status  qtr_id  month_id  year_id  \
# ordernumber
# 10107         2/24/2003 0:00   Shipped       1         2     2003
# ...

# %%
sales.dropna(inplace=True)

# %%
sales
# Out:
#       ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#             orderdate   status  qtr_id  month_id  year_id  ...  \
# ...

# %%
sales.dropna(axis=1)
# Out:
#       ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#             orderdate   status  qtr_id  month_id  year_id  ...  \
# ...

# %%
len(sales.columns)
# Out:
# 25

# %% [markdown]
# ## 6.IMPUTATION

# %%
values = sales['postalcode']

# %%
values
# Out:
# 10      3004
# 21      2067
# 40      2067
# 47      3004
# 51      2060
#         ...
# 2667    3004
# 2673    3004
# 2685    2067
# 2764    2067
# 2791    2067
# Name: postalcode, Length: 147, dtype: object

# %%
values = pd.to_numeric(values, errors='coerce')

# %%
mean = values.mean()

# %%
mean
# Out:
# 2415.387755102041

# %% [markdown]
# ## 7. SUMMARY STATISTICS

# %%
sales.describe(include='all')
# Out:
#          ordernumber  quantityordered   priceeach  orderlinenumber  \
# count     147.000000       147.000000  147.000000       147.000000
# unique           NaN              NaN         NaN              NaN
# top              NaN              NaN         NaN              NaN
# freq             NaN              NaN         NaN              NaN
# mean    10268.204082        33.986395   84.138639         6.673469
# std       106.742036         9.740458   19.897255         3.830596
# min     10120.000000        15.000000   26.880000         1.000000
# 25%     10148.000000        26.000000   66.390000         3.000000
# 50%     10270.000000        33.000000   98.050000         6.000000
# 75%     10361.000000        41.000000  100.000000        10.000000
# max     10420.000000        66.000000  100.000000        15.000000
#
#               sales       orderdate   status      qtr_id    month_id  \
# count    147.000000             147      147  147.000000  147.000000
# ...

# %%
sales.loc[:, sales.dtypes == np.float64]
# Out:
#       priceeach    sales
# 10       100.00  3965.66
# 21        72.55  1451.00
# 40       100.00  4905.39
# 47       100.00  3944.70
# 51       100.00  2416.56
# ...         ...      ...
# 2667      76.00  3268.00
# 2673      67.20  1747.20
# 2685     100.00  5001.92
# 2764     100.00  4277.35
# 2791      95.20  2189.60
#
# [147 rows x 2 columns]

# %%
sales.select_dtypes(include=['number']).dtypes
# Out:
# ordernumber          int64
# quantityordered      int64
# priceeach          float64
# orderlinenumber      int64
# sales              float64
# qtr_id               int64
# month_id             int64
# year_id              int64
# msrp                 int64
# dtype: object

# %%
sales.select_dtypes(include=[np.float64])
# Out:
#       priceeach    sales
# 10       100.00  3965.66
# 21        72.55  1451.00
# 40       100.00  4905.39
# 47       100.00  3944.70
# 51       100.00  2416.56
# ...         ...      ...
# 2667      76.00  3268.00
# 2673      67.20  1747.20
# 2685     100.00  5001.92
# 2764     100.00  4277.35
# 2791      95.20  2189.60
#
# [147 rows x 2 columns]

# %%
sales.plot(kind='scatter', x='priceeach', y='sales', title='Sales vs Priceeach');

# %%
sales['priceeach'].plot(kind='hist', title='Price Each');

# %%
sales['priceeach'].describe()
# Out:
# count    147.000000
# mean      84.138639
# std       19.897255
# min       26.880000
# 25%       66.390000
# 50%       98.050000
# 75%      100.000000
# max      100.000000
# Name: priceeach, dtype: float64

# %%
sales['priceeach'].plot(kind="box");

# %%
sales.boxplot(column='sales', by='priceeach')
# Out:
# <Axes: title={'center': 'sales'}, xlabel='priceeach'>

# %%
import seaborn as sns
# %matplotlib inline
# calculate the correlation matrix on the numeric columns
corr = sales.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sales[['quantityordered','sales']]
# Out:
#       quantityordered    sales
# 10                 37  3965.66
# 21                 20  1451.00
# 40                 21  4905.39
# 47                 30  3944.70
# 51                 24  2416.56
# ...               ...      ...
# 2667               43  3268.00
# 2673               26  1747.20
# 2685               44  5001.92
# 2764               35  4277.35
# 2791               23  2189.60
#
# [147 rows x 2 columns]

# %%
qs = sales[['quantityordered','sales']]
type(qs)
# Out:
# pandas.core.frame.DataFrame

# %%
condition = (sales['quantityordered'] > 50) | (sales['quantityordered'] < 100)
condition.count()
# Out:
# 147
